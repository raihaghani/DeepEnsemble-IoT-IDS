# %%
import os, time, random, math, gc
import numpy as np, pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.feature_selection import SelectKBest, mutual_info_classif
from sklearn.utils.class_weight import compute_class_weight
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, recall_score
import joblib
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# 2025-11-30 13:12:51.387417: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-30 13:12:51.804721: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-30 13:12:53.935515: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
# STREAM & BALANCE: create a balanced CSV on disk without loading everything in memory
import os, glob, math, random, gc
import pandas as pd, numpy as np
from pathlib import Path

DATA_DIR = "/home/rafia-khan/S7/Cnt/kaggle"   # your input folder
OUT_BALANCED = "cic_iot_balanced.csv"    # output smaller balanced file
SAMPLE_FRAC = 1.0          # keep 1.0 here; we'll undersample majority classes to cap
UNDERSAMPLE_CAP = 50000    # same as paper-style
CHUNKSIZE = 200_000       # adjust to available RAM (100k - 500k)
RANDOM_STATE = 42

# 1) find CSV files
csv_files = glob.glob(os.path.join(DATA_DIR, "*.csv"))
if not csv_files:
    raise FileNotFoundError("No CSV files found in " + DATA_DIR)
print("Found", len(csv_files), "csv files.")

# 2) quick scan first file to detect candidate numeric columns and label column
sample = pd.read_csv(csv_files[0], nrows=2000)
print("Sample columns:", sample.columns.tolist()[:40])

# heuristics for label column (you can modify if different)
label_candidates = ['label','Label','attack','Attack','Type','type','category','Category','Class','class']
label_col = None
for c in label_candidates:
    if c in sample.columns:
        label_col = c; break
if label_col is None:
    for c in sample.columns:
        if 'label' in c.lower() or 'attack' in c.lower() or 'type' in c.lower():
            label_col = c; break
if label_col is None:
    raise RuntimeError("Label column not found automatically. Please set label_col manually.")
print("Detected label column:", label_col)

# detect numeric candidate columns (drop obvious non-features)
drop_guesses = {'src_ip','dst_ip','timestamp','time','date','flow_id','__source_file__'}
numeric_candidates = [c for c in sample.columns if c not in drop_guesses and pd.api.types.is_numeric_dtype(sample[c])]
print("Numeric candidate count (sample):", len(numeric_candidates))
print("Numeric sample:", numeric_candidates[:40])

# 3) two-pass approach:
#   Pass A: compute per-class total counts by streaming
#   Pass B: stream again and write undersampled rows to balanced CSV

# PASS A: count class totals
from collections import Counter
class_counts = Counter()
for f in csv_files:
    print("Counting classes in", os.path.basename(f))
    for chunk in pd.read_csv(f, usecols=[label_col], chunksize=CHUNKSIZE):
        class_counts.update(chunk[label_col].astype(str).value_counts().to_dict())
print("Class counts (sample):", list(class_counts.items())[:10])

# Determine desired keep counts per class (paper-style)
keep_counts = {}
for cls, cnt in class_counts.items():
    if cnt > UNDERSAMPLE_CAP:
        keep_counts[cls] = UNDERSAMPLE_CAP
    else:
        keep_counts[cls] = cnt
print("Example keep counts (first 10):", list(keep_counts.items())[:10])
total_keep = sum(keep_counts.values())
print("Total rows after balancing (approx):", total_keep)

# PASS B: stream again and write undersampled sample per class
# We'll keep per-class reservoir sampling / counters to choose rows deterministically.
# For classes needing full keep_counts == original count we can write all rows.
if os.path.exists(OUT_BALANCED):
    os.remove(OUT_BALANCED)

# We'll track how many we've written per class
written_counts = Counter()

for f in csv_files:
    print("Processing", os.path.basename(f))
    # read in chunks, but keep only numeric candidates + label + maybe source
    usecols = [label_col] + numeric_candidates  # if too many features, trim numeric_candidates list manually
    reader = pd.read_csv(f, usecols=[c for c in usecols if c in pd.read_csv(f, nrows=0).columns], chunksize=CHUNKSIZE)
    for chunk in reader:
        # ensure label is string for consistent keys
        chunk[label_col] = chunk[label_col].astype(str)
        # iterate groups to avoid large memory copies
        for cls, group in chunk.groupby(label_col):
            to_keep = keep_counts.get(cls, 0)
            already = written_counts.get(cls, 0)
            remain = to_keep - already
            if remain <= 0:
                continue
            gsize = len(group)
            if gsize <= remain:
                # write entire group
                mode = 'a' if os.path.exists(OUT_BALANCED) else 'w'
                header = not os.path.exists(OUT_BALANCED)
                group.to_csv(OUT_BALANCED, mode=mode, header=header, index=False)
                written_counts[cls] += gsize
            else:
                # undersample uniformly from this chunk (deterministic seed)
                sel = group.sample(n=remain, random_state=RANDOM_STATE)
                mode = 'a' if os.path.exists(OUT_BALANCED) else 'w'
                header = not os.path.exists(OUT_BALANCED)
                sel.to_csv(OUT_BALANCED, mode=mode, header=header, index=False)
                written_counts[cls] += remain
        # small GC
        del chunk
        gc.collect()

print("Finished writing balanced file:", OUT_BALANCED)
print("Written counts sample:", list(written_counts.items())[:10])
# Out:
# Found 169 csv files.
# Sample columns: ['flow_duration', 'Header_Length', 'Protocol Type', 'Duration', 'Rate', 'Srate', 'Drate', 'fin_flag_number', 'syn_flag_number', 'rst_flag_number', 'psh_flag_number', 'ack_flag_number', 'ece_flag_number', 'cwr_flag_number', 'ack_count', 'syn_count', 'fin_count', 'urg_count', 'rst_count', 'HTTP', 'HTTPS', 'DNS', 'Telnet', 'SMTP', 'SSH', 'IRC', 'TCP', 'UDP', 'DHCP', 'ARP', 'ICMP', 'IPv', 'LLC', 'Tot sum', 'Min', 'Max', 'AVG', 'Std', 'Tot size', 'IAT']
# Detected label column: label
# Numeric candidate count (sample): 46
# Numeric sample: ['flow_duration', 'Header_Length', 'Protocol Type', 'Duration', 'Rate', 'Srate', 'Drate', 'fin_flag_number', 'syn_flag_number', 'rst_flag_number', 'psh_flag_number', 'ack_flag_number', 'ece_flag_number', 'cwr_flag_number', 'ack_count', 'syn_count', 'fin_count', 'urg_count', 'rst_count', 'HTTP', 'HTTPS', 'DNS', 'Telnet', 'SMTP', 'SSH', 'IRC', 'TCP', 'UDP', 'DHCP', 'ARP', 'ICMP', 'IPv', 'LLC', 'Tot sum', 'Min', 'Max', 'AVG', 'Std', 'Tot size', 'IAT']
# Counting classes in part-00059-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00048-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00140-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00139-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00099-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00007-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00101-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00064-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00081-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00102-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00057-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00078-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00109-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00072-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00006-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00047-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00085-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00098-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00116-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00120-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00049-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00035-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00105-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00065-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00051-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00145-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00148-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00126-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00088-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00167-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00058-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00113-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00056-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00082-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00143-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00077-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00039-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00097-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00112-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00133-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00158-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00110-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00095-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00030-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00157-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00062-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00080-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00068-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00123-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00012-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00043-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00027-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00131-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00054-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00151-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00108-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00071-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00066-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00053-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00124-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00034-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00010-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00166-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00138-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00155-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00129-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00009-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00025-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00031-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00106-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00115-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00032-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00044-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00036-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00094-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00096-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00020-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00037-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00162-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00011-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00114-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00147-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00033-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00146-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00128-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00107-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00086-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00016-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00100-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00050-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00132-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00017-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00074-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00060-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00041-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00104-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00079-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00029-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00002-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00087-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00052-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00061-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00127-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00125-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00103-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00156-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00111-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00022-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00014-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00019-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00154-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00144-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00159-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00152-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00163-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00055-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00122-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00038-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00153-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00091-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00119-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00090-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00004-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00003-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00028-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00164-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00137-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00092-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00093-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00045-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00026-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00021-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00136-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00015-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00168-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00118-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00005-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00076-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00135-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00013-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00070-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00073-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00141-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00069-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00150-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00142-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00117-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00089-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00067-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00023-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00083-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00161-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00000-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00084-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00024-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00042-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00075-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00121-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00001-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00008-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00165-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00134-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00149-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00160-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00130-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00040-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00018-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00046-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Counting classes in part-00063-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Class counts (sample): [('DDoS-ICMP_Flood', 7200504), ('DDoS-UDP_Flood', 5412287), ('DDoS-TCP_Flood', 4497667), ('DDoS-PSHACK_Flood', 4094755), ('DDoS-SYN_Flood', 4059190), ('DDoS-RSTFINFlood', 4045285), ('DDoS-SynonymousIP_Flood', 3598138), ('DoS-UDP_Flood', 3318595), ('DoS-TCP_Flood', 2671445), ('DoS-SYN_Flood', 2028834)]
# Example keep counts (first 10): [('DDoS-ICMP_Flood', 50000), ('DDoS-UDP_Flood', 50000), ('DDoS-TCP_Flood', 50000), ('DDoS-PSHACK_Flood', 50000), ('DDoS-SYN_Flood', 50000), ('DDoS-RSTFINFlood', 50000), ('DDoS-SynonymousIP_Flood', 50000), ('DoS-UDP_Flood', 50000), ('DoS-TCP_Flood', 50000), ('DoS-SYN_Flood', 50000)]
# Total rows after balancing (approx): 1279753
# Processing part-00059-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00048-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00140-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00139-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00099-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00007-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00101-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00064-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00081-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00102-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00057-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00078-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00109-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00072-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00006-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00047-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00085-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00098-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00116-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00120-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00049-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00035-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00105-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00065-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00051-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00145-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00148-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00126-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00088-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00167-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00058-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00113-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00056-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00082-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00143-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00077-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00039-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00097-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00112-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00133-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00158-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00110-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00095-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00030-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00157-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00062-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00080-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00068-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00123-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00012-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00043-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00027-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00131-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00054-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00151-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00108-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00071-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00066-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00053-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00124-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00034-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00010-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00166-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00138-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00155-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00129-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00009-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00025-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00031-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00106-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00115-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00032-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00044-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00036-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00094-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00096-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00020-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00037-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00162-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00011-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00114-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00147-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00033-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00146-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00128-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00107-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00086-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00016-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00100-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00050-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00132-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00017-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00074-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00060-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00041-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00104-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00079-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00029-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00002-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00087-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00052-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00061-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00127-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00125-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00103-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00156-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00111-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00022-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00014-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00019-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00154-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00144-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00159-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00152-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00163-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00055-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00122-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00038-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00153-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00091-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00119-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00090-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00004-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00003-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00028-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00164-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00137-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00092-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00093-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00045-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00026-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00021-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00136-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00015-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00168-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00118-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00005-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00076-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00135-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00013-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00070-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00073-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00141-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00069-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00150-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00142-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00117-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00089-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00067-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00023-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00083-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00161-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00000-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00084-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00024-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00042-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00075-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00121-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00001-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00008-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00165-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00134-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00149-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00160-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00130-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00040-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00018-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00046-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing part-00063-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Finished writing balanced file: cic_iot_balanced.csv
# Written counts sample: [('Backdoor_Malware', 3218), ('BenignTraffic', 50000), ('BrowserHijacking', 5859), ('CommandInjection', 5409), ('DDoS-ACK_Fragmentation', 50000), ('DDoS-HTTP_Flood', 28790), ('DDoS-ICMP_Flood', 50000), ('DDoS-ICMP_Fragmentation', 50000), ('DDoS-PSHACK_Flood', 50000), ('DDoS-RSTFINFlood', 50000)]

# %%
import pandas as pd, numpy as np

BALANCED_FILE = "cic_iot_balanced.csv"

# 1) load
df_bal = pd.read_csv(BALANCED_FILE)
print("Loaded balanced file:", BALANCED_FILE)
print("Shape:", df_bal.shape)

# 2) alias to df so existing code works without edits
df = df_bal
# Out:
# Loaded balanced file: cic_iot_balanced.csv
# Shape: (1279753, 47)

# %%
# --------- USER CONFIG ----------
BALANCED_FILE = "cic_iot_balanced.csv"
TOP_K_FEATURES = 40     # set None to use all numeric features
BATCH_SIZE = 512
EPOCHS = 20             # encoder training epochs (kept modest)
LR = 1e-4
EMBED_DIM = 64
TRANSFORMER_LAYERS = 1
TRANSFORMER_HEADS = 2
DROP_RATE = 0.4
RANDOM_STATE = 42
RF_EST = 200
VERBOSE = 2
# --------------------------------

np.random.seed(RANDOM_STATE); random.seed(RANDOM_STATE); tf.random.set_seed(RANDOM_STATE)
start_time = time.time()

# ---- 1) Load balanced dataset ----
if not os.path.exists(BALANCED_FILE):
    raise FileNotFoundError(f"{BALANCED_FILE} not found")
df = pd.read_csv(BALANCED_FILE)
print("Loaded:", BALANCED_FILE, "shape:", df.shape)
# Out:
# Loaded: cic_iot_balanced.csv shape: (1279753, 47)

# %%
# detect label column
label_col = None
for cand in ['label','Label','attack','Attack','Type','type','category','Category','Class','class']:
    if cand in df.columns:
        label_col = cand; break
if label_col is None:
    for c in df.columns:
        if 'label' in c.lower() or 'attack' in c.lower() or 'type' in c.lower():
            label_col = c; break
if label_col is None:
    raise RuntimeError("Label column not found in balanced CSV.")
print("Using label column:", label_col)

# ---- 2) select numeric features ----
drop_guesses = {'src_ip','dst_ip','timestamp','time','date','flow_id','__source_file__','__domain_synth__'}
numeric_candidates = [c for c in df.columns if c not in drop_guesses and pd.api.types.is_numeric_dtype(df[c])]
if not numeric_candidates:
    raise RuntimeError("No numeric features found.")
if TOP_K_FEATURES and len(numeric_candidates) > TOP_K_FEATURES:
    print("Selecting top features by mutual info...")
    tmp_y = LabelEncoder().fit_transform(df[label_col].astype(str).values)
    selector = SelectKBest(mutual_info_classif, k=TOP_K_FEATURES)
    selector.fit(df[numeric_candidates].fillna(0).values, tmp_y)
    chosen = [numeric_candidates[i] for i in selector.get_support(indices=True)]
else:
    chosen = numeric_candidates
print("Using {} features (sample): {}".format(len(chosen), chosen[:20]))
# Out:
# Using label column: label
# Selecting top features by mutual info...
# Using 40 features (sample): ['flow_duration', 'Header_Length', 'Protocol Type', 'Duration', 'Rate', 'Srate', 'fin_flag_number', 'syn_flag_number', 'rst_flag_number', 'psh_flag_number', 'ack_flag_number', 'cwr_flag_number', 'ack_count', 'syn_count', 'fin_count', 'urg_count', 'rst_count', 'HTTP', 'HTTPS', 'DNS']

# %%
# ---- 3) prepare arrays & split ----
df = df.dropna(subset=chosen + [label_col]).reset_index(drop=True)
X = df[chosen].astype(float).values
y_raw = df[label_col].astype(str).values
le_y = LabelEncoder(); y = le_y.fit_transform(y_raw)
X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=0.2, stratify=y, random_state=RANDOM_STATE)
print("Train/test shapes:", X_tr.shape, X_te.shape)
# Out:
# Train/test shapes: (1023802, 40) (255951, 40)
